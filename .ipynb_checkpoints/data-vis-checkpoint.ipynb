# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0  Embraer's E190-E2 Program Development Named 20...
# 1  Jet Aviation Announces Opening of New Teterbor...
# 2  GMF Solidifies Its Airframe Capabilities With ...
# 3  United Technologies nets $325.2M contract for ...
# 4  Boeing wants to double in size, and Australia ...
#
#                                              Summary  \
# 0  Project Management Institute (PMI), the world’...
# 1  Jet Aviation announces the opening of its new ...
# 2  GMF AeroAsia is adding hangars, subsidiaries a...
# 3  The Pratt & Whitney division of United Technol...
# 4  American aircraft manufacturer Boeing expects ...
#
#                             Source                         Source.1  \
# 0                   Business Wire                    Business Wire
# 1                 AviationPros.com                 AviationPros.com
# 2                      MRO Network                      MRO Network
# 3                        Breitbart                        Breitbart
# 4  The Australian Financial Review  The Australian Financial Review
#
#             Topic Business line
# 0  Self-awareness    Commercial
# 1       Expansion     Executive
# 2    New facility    Commercial
# 3        Contract      Military
# 4       Expansion    Commercial

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 6 columns):
# Title            748 non-null object
# Summary          748 non-null object
# Source           748 non-null object
# Source.1         476 non-null object
# Topic            747 non-null object
# Business line    745 non-null object
# dtypes: object(6)
# memory usage: 35.1+ KB

# %%
df[df['Source'] != df['Source.1']][df['Source.1'].notnull()]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Title, Summary, Source, Source.1, Topic, Business line]
# Index: []

# %% [markdown]
# # As we can see, there is no row whose value in 'Source' is different from that in 'Source.1'. Due to that, we can remove 'Source.1' column

# %%
df = df.drop(labels='Source.1', axis=1)
df.dropna(axis=0, inplace=True)

# %%
print("There are {} words".format(df['Summary'].apply(lambda x: len(x.split(' '))).sum()))
# Out:
# There are 24633 words

# %%
plt.figure(figsize=(18, 12))
ax = plt.axes()
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
df.Topic.value_counts().plot(kind='bar');
plt.savefig('./data-vis-pictures/topic_distribuition_1.png', transparent=True)

# %%
df.describe()
# Out:
#                                               Title  \
# count                                           745
# unique                                          744
# top     Embraer Announces Senior Management Shuffle
# freq                                              2
#
#                                                   Summary  \
# count                                                 745
# unique                                                740
# top     West Star announces their first Aft Canted Bul...
# freq                                                    2
#
#                              Source Topic Business line
# count                           745   745           745
# unique                          315    42             7
# top     Aviation International News  Deal       Generic
# freq                             66    72           265

# %%
df['length'] = df['Summary'].apply(len)
df.head()
# Out:
#                                                Title  \
# 0  Embraer's E190-E2 Program Development Named 20...
# 1  Jet Aviation Announces Opening of New Teterbor...
# 2  GMF Solidifies Its Airframe Capabilities With ...
# 3  United Technologies nets $325.2M contract for ...
# 4  Boeing wants to double in size, and Australia ...
#
#                                              Summary  \
# 0  Project Management Institute (PMI), the world’...
# 1  Jet Aviation announces the opening of its new ...
# 2  GMF AeroAsia is adding hangars, subsidiaries a...
# 3  The Pratt & Whitney division of United Technol...
# 4  American aircraft manufacturer Boeing expects ...
#
#                             Source           Topic Business line  length
# 0                   Business Wire   Self-awareness     Comercial     273
# 1                 AviationPros.com       Expansion     Executive     237
# 2                      MRO Network    New facility     Comercial     113
# 3                        Breitbart        Contract      Military     182
# 4  The Australian Financial Review       Expansion     Comercial     244

# %% [markdown]
# Following Sturges Criterion: k = 1 + 3.322*log10(n)

# %%
import math
k = math.ceil(1 + 3.322*np.log10(df.shape[0]))
ax.set_ylabel('Y-axis')
ax = plt.axes()
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.yaxis.label.set_color('white')
df['length'].plot(bins=k, kind='hist', colormap='Pastel2');
plt.savefig('./data-vis-pictures/length.png', transparent=True)

# %% [markdown]
# There are some big summaries in the data. Let's investigate it

# %%
df.length.describe()
# Out:
# count    745.000000
# mean     216.660403
# std       79.132792
# min       67.000000
# 25%      159.000000
# 50%      207.000000
# 75%      264.000000
# max      541.000000
# Name: length, dtype: float64

# %%
df[df['length'] == 541]['Summary'].iloc[0]
# Out:
# '“There are a lot of great aviation programs around doing good work, but the numbers and pilot diversity have not changed,” said Gary Morrison, Aviation Accreditation Board International chairperson. “That is not the case with Air Force Junior ROTC. The program provides quantifiable measurements of success and access to the single largest group of competitive and diverse students. AABI is excited to be an integral part in this very innovative program to reach students who might not otherwise be able to fulfill their dreams in aviation.”'

# %%
df[df['length'] == 541]
# Out:
#                                                  Title  \
# 471  CSAF Private Pilot Scholarship Program changin...
#
#                                                Summary         Source  \
# 471  “There are a lot of great aviation programs ar...  Stripes Korea
#
#         Topic Business line  length
# 471  Training       Generic     541

# %%
df.hist(column='length', by='Topic', bins=50,figsize=(40,20));

# %%
plt.figure(figsize=(16, 8))
ax = plt.axes()
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
df['Business line'].value_counts().plot(kind='bar');
plt.savefig('./data-vis-pictures/business_line_1.png', transparent=True)

# %%
df['Business line'] = df['Business line'].replace({'Commercial': 'Comercial'})

# %%
plt.figure(figsize=(16, 8))
df['Business line'].value_counts().plot(kind='bar');

# %%
df.shape
# Out:
# (745, 5)

# %%
df = df[df['Business line'] != 'Agriculture']

# %%
plt.figure(figsize=(16, 8))
ax = plt.axes()
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
df['Business line'].value_counts().plot(kind='bar');
plt.savefig('./data-vis-pictures/business_line_2.png', transparent=True)
